# %%
# För att använda dataset från kaggle måste vi först hämta datan därifrån. 
# Man trycker download och kopierar koden. Kär den sedan så att datasetet laddas ner: 

import kagglehub

# Download latest version
path = kagglehub.dataset_download("zazueta/pisa-scores-2015")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\fanny\.cache\kagglehub\datasets\zazueta\pisa-scores-2015\versions\1

# %% [markdown]
# Läser in CSV-filer:

# %%
import pandas as pd

# Läs in definition- och källdata
definition_df = pd.read_csv("pisa_definition.csv")

# Läs in datatabellen
data_df = pd.read_csv("pisa_data.csv")

# %%
print("Definitioner och källor:")
display(definition_df.head())

print("\nPISA-data:")
display(data_df.head())
# Out:
# Definitioner och källor:
#              Code                                     Indicator Name  \
# 0     LO.PISA.MAT    PISA: Mean performance on the mathematics scale
# 1  LO.PISA.MAT.FE  PISA: Mean performance on the mathematics scal...
# 2  LO.PISA.MAT.MA  PISA: Mean performance on the mathematics scal...
# 3     LO.PISA.REA        PISA: Mean performance on the reading scale
# 4  LO.PISA.REA.FE  PISA: Mean performance on the reading scale. F...
#
#                                      Long definition  \
# 0  Average score of 15-year-old students on the P...
# 1  Average score of 15-year-old female students o...
# 2  Average score of 15-year-old male students on ...
# 3  Average score of 15-year-old students on the P...
# 4  Average score of 15-year-old female students o...
#
#                                               Source
# 0  OECD Programme for International Student Asses...
# 1  OECD Programme for International Student Asses...
# ...

# %%
display(data_df)
# Out:
#                                            Country Name Country Code  \
# 0                                               Albania          ALB
# 1                                               Albania          ALB
# 2                                               Albania          ALB
# 3                                               Albania          ALB
# 4                                               Albania          ALB
# ...                                                 ...          ...
# 1161                                                NaN          NaN
# 1162                                                NaN          NaN
# 1163                                                NaN          NaN
# 1164  Data from database: Education Statistics: Lear...          NaN
# 1165                           Last Updated: 12/12/2016          NaN
#
#                                             Series Name     Series Code  \
# ...

# %%
display(data_df[['Country Name', '2015 [YR2015]']])
# Out:
#                                            Country Name     2015 [YR2015]
# 0                                               Albania           413.157
# 1                                               Albania  417.750029482799
# 2                                               Albania  408.545458736189
# 3                                               Albania          405.2588
# 4                                               Albania  434.639625546737
# ...                                                 ...               ...
# 1161                                                NaN               NaN
# 1162                                                NaN               NaN
# 1163                                                NaN               NaN
# 1164  Data from database: Education Statistics: Lear...               NaN
# 1165                           Last Updated: 12/12/2016               NaN
#
# [1166 rows x 2 columns]

# %%
data_df.describe
# Out:
# <bound method NDFrame.describe of                                            Country Name Country Code  \
# 0                                               Albania          ALB
# 1                                               Albania          ALB
# 2                                               Albania          ALB
# 3                                               Albania          ALB
# 4                                               Albania          ALB
# ...                                                 ...          ...
# 1161                                                NaN          NaN
# 1162                                                NaN          NaN
# 1163                                                NaN          NaN
# 1164  Data from database: Education Statistics: Lear...          NaN
# 1165                           Last Updated: 12/12/2016          NaN
#
#                                             Series Name     Series Code  \
# ...

# %%
col = "2015 [YR2015]"

# (valfritt) trimma ev. blanksteg i kolumnnamn
data_df.columns = data_df.columns.str.strip()

# Rensa vanliga “skräptecken” och gör om till numeriskt
s = (
    data_df[col]
    .astype(str)
    .str.replace(r"[^\d\-,.]", "", regex=True)  # ta bort allt utom siffror, minus, komma, punkt
    .str.replace(",", ".", regex=False)         # ersätt decimalkomma med punkt
)

s = pd.to_numeric(s, errors="coerce")  # icke-tolkningsbara värden blir NaN

s.agg(["mean", "max", "min"])
# Out:
# mean    462.102626
# max     564.254534
# min     325.586561
# Name: 2015 [YR2015], dtype: float64

# %%
stocks = pd.concat(data_df, axis=1)
stocks
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 stocks = pd.concat(data_df, axis=1)
#       2 stocks
#
# File c:\Users\fanny\data-mining-FANNY-DEGERMAN\.venv\Lib\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# ...

# %%
data_df.agg({"2015 [YR2015]": ["mean", "min", "max"]})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 data_df.agg({"2015 [YR2015]": ["mean", "min", "max"]})
#
# File c:\Users\fanny\data-mining-FANNY-DEGERMAN\.venv\Lib\site-packages\pandas\core\frame.py:10176, in DataFrame.aggregate(self, func, axis, *args, **kwargs)
#   10173 axis = self._get_axis_number(axis)
#   10175 op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# > 10176 result = op.agg()
#   10177 result = reconstruct_and_relabel_result(result, func, **kwargs)
#   10178 return result
#
# File c:\Users\fanny\data-mining-FANNY-DEGERMAN\.venv\Lib\site-packages\pandas\core\apply.py:928, in FrameApply.agg(self)
#     926 result = None
#     927 try:
# --> 928     result = super().agg()
#     929 finally:
#     930     self.obj = obj
#
# ...

# %%
df[(df["Category"] == "Electronics") & (df["Country"] == "USA")]
# Out:
#   Cell In[19], line 1
#     data_df[(data_df["Country Name"] == "Albania") & (data_df["2015 [YR2015]"]
#                                                                               ^
# _IncompleteInputError: incomplete input
